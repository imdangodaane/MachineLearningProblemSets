# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)
#
# # SF Salaries Exercise
#
# Explore San Francisco city employee salary data.
#
# ## Overview
#
# One way to understand how a city government works is by looking at who it employs and how its employees are compensated. This data contains the names, job title, and compensation for San Francisco city employees on an annual basis from 2011 to 2014.
#
#
#
# Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.
#
# ## Resourses
#
# [Pandas API Reference](https://pandas.pydata.org/pandas-docs/stable/api.html)
#
# [NumPy Reference](https://docs.scipy.org/doc/numpy/reference/)
#
# [Visualization with Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)

# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read `Salaries.csv` as a dataframe called `sal`.**

# %%
# link = "https://s3-ap-southeast-1.amazonaws.com/intro-to-ml-minhdh/Salaries.csv"
sal = pd.read_csv("https://s3-ap-southeast-1.amazonaws.com/intro-to-ml-minhdh/Salaries.csv")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**
#
# Keyword: [mean](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html)

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **What is the lowest and highest amount of BasePay?**
#
# Keyword:
# [min](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.min.html) ,
# [max](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.max.html)

# %%
sal['BasePay'].min()
# Out:
# -166.01

# %%
sal['BasePay'].max()
# Out:
# 319275.01

# %% [markdown]
# **How about OvertimePay in the dataset? What is the average, lowest, highest amount?**

# %%
sal['OvertimePay'].mean()
# Out:
# 5066.059886444622

# %%
sal['OvertimePay'].min()
# Out:
# -0.01

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).**

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
# Now try to select Employees who have name "GARY JIMENEZ"
# Your code here
sal[sal['EmployeeName']=='GARY JIMENEZ']
# Out:
#    Id  EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 1  137811.38       NaN  538909.28         538909.28  2011    NaN
#
#           Agency  Status
# 1  San Francisco     NaN

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# **What is the name of highest paid person (including benefits)?**

# %%
sal.sort_values(by='TotalPayBenefits', ascending=False).head(1)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %% [markdown]
# **What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.sort_values(by='TotalPayBenefits', ascending=False).tail(1)
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014) ?**
# Keyword: _groupby_

# %%
sal2 = sal.groupby('Year').mean()
sal2
# Out:
#             Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.0  63595.956517  4531.065429  3617.081926           NaN
# 2012   54542.5  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91728.5  69630.030216  5281.641980  3819.969007  23829.076572
# 2014  129593.0  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits  Notes  Status
# Year
# 2011  71744.103871      71744.103871    NaN     NaN
# 2012  74113.262265     100553.229232    NaN     NaN
# 2013  77611.443142     101440.519714    NaN     NaN
# 2014  75463.918140     100250.918884    NaN     NaN

# %% [markdown]
# **How many unique job titles are there?**
#
# Keyword: _unique, nunique_

# %%
sal['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# **What are the top 5 most common jobs?**
#
# Keyword: *value_counts*

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# **How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)**

# %%
job_count = sal['JobTitle'].value_counts()
job_count.tail(240)
# Out:
# REAL PROPERTY OFFICER                                 2
# ASSISTANT SUPERINTENDENT RECREATION                   1
# CHIEF PLUMBING INSPECTOR                              1
# ORTHOPEDIC TECHNICIAN I                               1
# MUNICIPAL STADIUM GROUNDSKEEPER                       1
# SENIOR OPERATIONS MANAGER                             1
# Special Assistant 13                                  1
# PRINCIPAL RECREATION SUPERVISOR                       1
# TELECOMMUNICATIONS TECHNICIAN SUPERVISOR              1
# MAYOR'S PROGRAM MANAGER                               1
# Cfdntal Sctry to Distric Atty                         1
# SECRETARY, COMMISSION ON THE ENVIRONMENT              1
# DIRECTOR, JUVENILE HALL                               1
# COURT REPORTER COORDINATOR                            1
# ELECTRICAL ENGINEERING ASSOCIATE I                    1
# Head Airport Electrician                              1
# WAREHOUSE WORKER                                      1
# ...

# %%
job_count = sal['JobTitle'].value_counts()
sal[sal['JobTitle'].isin(job_count.index[job_count == 1])]
# Out:
#             Id           EmployeeName  \
# 7            8          DAVID KUSHNER
# 9           10     JOANNE HAYES-WHITE
# 25          26           GREGORY SUHR
# 36          37           SUSAN CURRIN
# 73          74          MONIQUE MOYER
# 136        137          NIKOLAS LEMOS
# 179        180         DENNIS HERRERA
# 197        198          THOMAS HARVEY
# 266        267           NELSON ACETO
# 282        283         JEFFREY ADACHI
# 293        294      MICHAEL HENNESSEY
# 306        307      MARGARET CALLAHAN
# 398        399     WILLIAM SIFFERMANN
# 433        434        LEONARD BROBERG
# 488        489            MARTIN GRAN
# 803        804          TERRENCE YUEN
# 960        961        JONATHAN FERDON
# 1123      1124            ALLEN NANCE
# 1142      1143                 RON HO
# 1240      1241            PHILIP TING
# 1551      1552          JOSE CISNEROS
# 1712      1713          JAMES CRISOLO
# 1894      1895         ROBERTA BOOMER
# ...

# %% [markdown]
# **How many people have the word Chief in their job title?**

# %%
sal[sal['JobTitle'].str.contains('Chief')]['JobTitle'].count()
# Out:
# 423

# %% [markdown]
# ## Data Visualization
#
# **Implement seaborn's countplot with x='Year'**

# %%
sns.countplot(x='Year', data=sal)

# %% [markdown]
# **Implement seaborn's distplot for BasePay of Year 2011**

# %%
year_groupby = sal.groupby('Year')['BasePay'].sum().plot(kind='bar')

# %% [markdown]
# **How about other Year**

# %%
sns.distplot(sal.groupby('Year')['BasePay'].sum(), bins=5)

# %% [markdown]
# ## Bonus
#
# **Visualize top 5 Jobs with BasePay, Benefits and OvertimePay**
#
# Keyword: *index, isin, groupby, mean, plot*

# %%
sal['TotalBenefits'] = sal['BasePay'] + sal['Benefits'] + sal['OvertimePay']
top_5 = sal.sort_values(by='TotalBenefits', ascending=False)['JobTitle'].unique()[:5]
a = sal[sal['JobTitle'].isin(top_5)][['JobTitle','BasePay', 'Benefits', 'OvertimePay']]
a.groupby('JobTitle').mean().plot(kind='bar')

# %% [markdown]
# **Fun Fact: Is there a correlation between length of the Job Title string and Salary?**
#
# *Hint: corr()*

# %%
sal['LengthJobTitle'] = sal['JobTitle'].str.len()
plt.figure(figsize=(14,14))
sal.corr()
sns.heatmap(sal.corr(), annot=True, fmt='.3f', cmap='YlGnBu')

# %% [markdown]
# # Great Job!
